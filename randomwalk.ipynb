# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %timeit
np.random.seed(371789)
amostra = np.random.randint(-1, 1, 1000)

# %%
amostra = np.where(amostra == 0, 1, amostra)
rand_walk = amostra.cumsum()

# %%
plt.plot(rand_walk)
