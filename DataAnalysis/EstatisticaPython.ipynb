# %% [markdown]
# # Estatística com Python

# %% [markdown]
# O conjunto de dados foi disponibilizado pelo professor Cesar Cerqueira durante a cadeira do curso de Ciência da Computação da Universidade católica de Pernambuco. As bibliotecas Numpy e Pandas serão utilizadas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'C:\Users\João Gabriel Torres\Desktop\PythonBizarreAdventures\Bases\basealunos23.xlsx')
df
# Out:
#     Id  Turma Sexo  Idade   Alt  Peso  Filhos_Fam Mora Escol_mae  Exerc  Cine  \
# 0    1  Manha    M     17  1.60  61.0           2  INT      FUND      0     1
# 1    2  Manha    M     18  1.69  56.0           1  RMR       SUP      0     1
# 2    3  Manha    F     18  1.85  73.0           2  RMR     MEDIO      5     2
# 3    4  Manha    F     25  1.85  84.0           2  RMR     MEDIO      5     2
# 4    5  Manha    F     19  1.58  55.0           1  RMR       SUP      2     2
# 5    6  Manha    M     19  1.76  61.0           3  RMR     MEDIO      2     1
# 6    7  Manha    F     20  1.60  58.0           1  RMR       SUP      3     1
# 7    8  Manha    F     27  1.64  47.0           1  RMR       SUP      2     2
# 8    9  Manha    M     32  1.62  57.8           3  RMR     MEDIO      3     3
# 9   10  Manha    F     36  1.64  58.0           2  RMR       SUP      2     2
# 10  11  Manha    F     39  1.72  70.0           1  INT       SUP     10     2
# ...

# %% [markdown]
# ## Informações básicas

# %% [markdown]
# A base de dados possui 50 entradas. Cada entrada corresponde a um aluno. A variáveis são Id, Turma, Sexo, Idade, Peso etc. Vamos começar analisando a variável peso.

# %%
serie1 = df.loc[:, "Peso"]

# %% [markdown]
# A função describe é bastante útil, pois ela exibe uma tabela contendo informações básicas, como quantidade de entradas, média, desvio padrão (std), quartis etc, de cada variável.

# %%
df.describe()
# Out:
#              Id      Idade        Alt       Peso  Filhos_Fam      Exerc  \
# count  50.00000  50.000000  50.000000  50.000000   50.000000  50.000000
# mean   25.50000  24.800000   1.672000  61.114000    1.700000   3.800000
# std    14.57738   7.553888   0.090599  12.288239    1.092647   2.770103
# min     1.00000  17.000000   1.450000  44.000000    1.000000   0.000000
# 25%    13.25000  18.000000   1.602500  52.125000    1.000000   2.000000
# 50%    25.50000  22.000000   1.665000  58.000000    1.000000   3.500000
# 75%    37.75000  32.000000   1.717500  68.875000    2.000000   5.750000
# max    50.00000  39.000000   1.850000  94.000000    7.000000  10.000000
#
#             Cine  Nota Calc1  Horas_estudo  RendaFam
# count  50.000000   50.000000     50.000000  50.00000
# mean    1.740000    6.670000     11.180000   8.29600
# std     1.084398    2.295981      6.100151   5.65068
# min     0.000000    1.500000      1.000000   1.00000
# ...

# %% [markdown]
# Para obter os valores individuais o pandas possui as funções count(), mean(), std(), min(), quantile() e max(). Outro dado importante é a mediana, que podemos obter usando a função median().

# %%
amostras = serie1.count()
amostras
# Out:
# 50

# %%
media = serie1.mean()
media
# Out:
# 61.114

# %%
desvpad = serie1.std()
desvpad
# Out:
# 12.288239109333903

# %%
min = serie1.min()
min
# Out:
# 44.0

# %%
quartis = serie1.quantile([0.25, 0.5, 0.75])
quartis
# Out:
# 0.25    52.125
# 0.50    58.000
# 0.75    68.875
# Name: Peso, dtype: float64

# %%
max = serie1.max()
max
# Out:
# 94.0

# %%
mediana = serie1.median()
mediana
# Out:
# 58.0

# %%
serie1.var()
# Out:
# 151.00082040816326

# %%
sns.histplot(data=df, x="Idade", hue="Sexo")
# Out:
# <Axes: xlabel='Idade', ylabel='Count'>

# %%
sns.scatterplot(data=df, x="Horas_estudo", y="Nota Calc1")
# Out:
# <Axes: xlabel='Horas_estudo', ylabel='Nota Calc1'>
